# %%
import streamlit as st
import pymongo
import pymysql

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#      |████████████████████████████████| 8.9 MB 5.2 MB/s eta 0:00:01
# Collecting rich<14,>=10.11.0
#   Downloading rich-13.5.2-py3-none-any.whl (239 kB)
#      |████████████████████████████████| 239 kB 9.1 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.4 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (2.22.0)
# Requirement already satisfied: pandas<3,>=0.25 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (1.0.1)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-12.0.1-cp37-cp37m-macosx_10_14_x86_64.whl (24.7 MB)
#      |████████████████████████████████| 24.7 MB 14.4 MB/s eta 0:00:01
# Collecting tzlocal<5,>=1.1
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Collecting gitpython!=3.1.19,<4,>=3
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      |████████████████████████████████| 188 kB 11.3 MB/s eta 0:00:01
# Collecting altair<6,>=4.0
#   Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#      |████████████████████████████████| 471 kB 10.6 MB/s eta 0:00:01
# Collecting pympler<2,>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 10.8 MB/s eta 0:00:01
# Collecting typing-extensions<5,>=4.0.1
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting pydeck<1,>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 11.2 MB/s eta 0:00:01
# Requirement already satisfied: click<9,>=7.0 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (7.0)
# Collecting tenacity<9,>=8.0.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting toml<2
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (1.5.0)
# Requirement already satisfied: pillow<10,>=6.2.0 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (7.0.0)
# Collecting protobuf<5,>=3.20
#   Downloading protobuf-4.24.1-py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 9.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil<3,>=2 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (2.8.1)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting validators<1,>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (6.0.3)
# Requirement already satisfied: numpy<2,>=1 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (1.18.1)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: packaging<24,>=14.1 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from streamlit) (20.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 9.1 MB/s  eta 0:00:01
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.16.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 10.5 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (1.25.8)
# Requirement already satisfied: pytz>=2017.2 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from pandas<3,>=0.25->streamlit) (2019.3)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo; python_version < "3.9"
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-macosx_10_14_x86_64.whl (35 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 6.6 MB/s  eta 0:00:01
# Requirement already satisfied: toolz in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (0.10.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (3.2.0)
# Requirement already satisfied: jinja2 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (2.11.1)
# Requirement already satisfied: zipp>=0.5 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata<7,>=1.4->streamlit) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil<3,>=2->streamlit) (1.14.0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from validators<1,>=0.2->streamlit) (4.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from packaging<24,>=14.1->streamlit) (2.4.6)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting tzdata; python_version >= "3.6"
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      |████████████████████████████████| 341 kB 11.1 MB/s eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=17.4.0 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.15.7)
# Requirement already satisfied: setuptools in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (46.0.0.post20200309)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from jinja2->altair<6,>=4.0->streamlit) (1.1.1)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19567 sha256=358ebc3ba68addb2a69535bcd0bee467207c7ee2029320930a5f6b35f085905a
#   Stored in directory: /Users/ashwinrajh/Library/Caches/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# ERROR: spyder 4.0.1 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 4.0.1 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# Installing collected packages: typing-extensions, mdurl, markdown-it-py, pygments, rich, pyarrow, backports.zoneinfo, tzdata, pytz-deprecation-shim, tzlocal, smmap, gitdb, gitpython, altair, pympler, pydeck, tenacity, toml, protobuf, cachetools, validators, blinker, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.5.2
#     Uninstalling Pygments-2.5.2:
#       Successfully uninstalled Pygments-2.5.2
# Successfully installed altair-5.0.1 backports.zoneinfo-0.2.1 blinker-1.6.2 cachetools-5.3.1 gitdb-4.0.10 gitpython-3.1.32 markdown-it-py-2.2.0 mdurl-0.1.2 protobuf-4.24.1 pyarrow-12.0.1 pydeck-0.8.1b0 pygments-2.16.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.5.2 smmap-5.0.0 streamlit-1.23.1 tenacity-8.2.3 toml-0.10.2 typing-extensions-4.7.1 tzdata-2023.3 tzlocal-4.3.1 validators-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
 import pymongo
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c15581d62f68> in <module>
#       1 import pymongo
# ----> 2 import pymysql
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 3.7 MB/s eta 0:00:011
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pymongo
import pymysql

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (4.4.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/ashwinrajh/opt/anaconda3/lib/python3.7/site-packages (from pymongo) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pymysql

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

Ytdb = myclient["Youtube_Db"]

# %%
myclient.list_database_names()
# Out:
# ['admin', 'config', 'local', 'mydatabase', 'mydatabase2', 'mydb']

# %%
pip install --upgrade google-api-python-client

# %%
from googleapiclient.discovery import build

# %%
api_key = "AIzaSyAm62tNRauhAqQBAXmnhOjb5GB3QLiezMs"

# %%
youtube = build('youtube','v3',developerKey =api_key )

# %% [markdown]
# # Function to get Channel Statistics

# %%
def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
                part = 'snippet,contentDetails,statistics',
                id = channel_id)
    response = request.execute()
    
    channel_data = dict(Channel_name = response['items'][0]['snippet']['title'],
               Subscribers = response['items'][0]['statistics']['subscriberCount'],
                Views = response['items'][0]['statistics']['viewCount'],
                Total_videos = response['items'][0]['statistics']['videoCount'],
                Playlist_ID = response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
                       )
    
    
    return channel_data

# %%
get_channel_stats(youtube, channel_id)
# Out:
# {'Channel_name': 'Ashwin Rajh',
#  'Subscribers': '0',
#  'Views': '12',
#  'Total_videos': '4',
#  'Playlist_ID': 'UUbZr6zxHZq0eFpVBeU-7IgQ'}

# %% [markdown]
# # Function to get PlaylistID & VideoID

# %%
def get_playlist_id(youtube, channel_id):
    request = youtube.channels().list(
        part='contentDetails',
        id=channel_id
    )
    response = request.execute()

    playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    return playlist_id

def get_video_ids(youtube, channel_id):
    playlist_id = get_playlist_id(youtube, channel_id)  # Call the function to get the playlist ID
    
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=50

    )
    response = request.execute()
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append((response['items'][i]['contentDetails']['videoId']))
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId=playlist_id,
                        maxResults=50,
                        pageToken = next_page_token
                         )
            response = request.execute()
                
            for i in range(len(response['items'])):
                video_ids.append((response['items'][i]['contentDetails']['videoId']))
    
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
get_video_ids(youtube, channel_id)
# Out:
# ['xNy-7LlnBfU', 'yOhEigi55pc', 'O1H4mZNAZDQ', 'ao1DADw9u54']

# %% [markdown]
# # Function to get Video Stats

# %%
from datetime import timedelta

def get_video_stats(youtube, channel_id):
    video_id = get_video_ids(youtube, channel_id)
    video_stat=[]
    for video in video_id:
        request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=video
        )
        response = request.execute()

    # Parse the time duration string
        time_string = response['items'][0]['contentDetails']['duration']
        duration = time_string[2:]  # Remove the "PT" prefix
        minutes_position = duration.find("M")
        seconds_position = duration.find("S")

        minutes = int(duration[0:minutes_position]) if minutes_position >= 0 else 0
        seconds = int(duration[minutes_position + 1:seconds_position]) if seconds_position >= 0 else 0

    # Calculate duration in seconds
        result = (minutes * 60) + seconds

    # Create a dictionary containing video data
        video_data = {
            "video_name": response['items'][0]['snippet']['title'],
            "Likes": response['items'][0]['statistics']['likeCount'],
            "Views": response['items'][0]['statistics']['viewCount'],
            "Total_Count": response['items'][0]['statistics']['commentCount'],
            "Duration": result  # Duration in seconds
            }
        video_stat.append(video_data)
    return video_stat

# %%
get_video_stats(youtube, 'UCF-uUxo43IPpnEwnR62WGlA')
# Out:
# [{'video_name': 'What is SAP PS Explained | Introduction to SAP PS Overview & Basics',
#   'Likes': '20',
#   'Views': '2588',
#   'Total_Count': '0',
#   'Duration': 492},
#  {'video_name': 'All SQL Fundamentals Explained in 10 Minutes | Learn SQL Basics for Beginners | SQL Crash Course',
#   'Likes': '69',
#   'Views': '7398',
#   'Total_Count': '11',
#   'Duration': 655},
#  {'video_name': 'Difference Between Proxy vs Reverse Proxy vs Load Balancer Explained | Networking Basics',
#   'Likes': '31',
#   'Views': '5660',
#   'Total_Count': '6',
#   'Duration': 441},
#  {'video_name': 'All DBMS Keys Explained | Primary, Super, Candidate, Alternate, Foreign, Composite & Unique Key',
#   'Likes': '30',
#   'Views': '4659',
#   'Total_Count': '5',
#   'Duration': 632},
#  {'video_name': 'Vertical Scaling vs Horizontal Scaling vs Diagonal Scaling | Types of Cloud Scalability',
#   'Likes': '27',
#   'Views': '4091',
#   'Total_Count': '8',
#   'Duration': 420},
#  {'video_name': 'Difference Between REST API vs Web API vs SOAP API Explained',
#   'Likes': '232',
#   'Views': '11163',
#   'Total_Count': '10',
#   'Duration': 444},
#  {'video_name': '8 Tips on How to Choose Neural Network Architecture',
#   'Likes': '65',
#   'Views': '5613',
#   'Total_Count': '7',
#   'Duration': 447},
#  {'video_name': 'All Major Data Mining Techniques Explained With Examples',
#   'Likes': '202',
#   'Views': '15552',
#   'Total_Count': '14',
#   'Duration': 784},
#  {'video_name': '54 Business Models Explained in 10 Minutes | Business Ideas for Beginners 2023',
#   'Likes': '64',
#   'Views': '7966',
#   'Total_Count': '6',
#   'Duration': 651},
#  {'video_name': 'Difference Between Software Architecture vs Software Design Explained #shorts',
#   'Likes': '147',
#   'Views': '3095',
#   'Total_Count': '4',
#   'Duration': 54},
#  {'video_name': 'All Major Blockchain Consensus Algorithms Explained | Consensus Mechanism in Blockchain',
#   'Likes': '56',
#   'Views': '6486',
#   'Total_Count': '9',
#   'Duration': 770},
#  {'video_name': 'What is SAP SuccessFactors Explained in 60 Seconds #shorts',
#   'Likes': '133',
#   'Views': '3730',
#   'Total_Count': '5',
#   'Duration': 52},
#  {'video_name': 'What is SAP HR Explained | Introduction to SAP HCM Overview & Basics',
#   'Likes': '261',
#   'Views': '14142',
#   'Total_Count': '8',
#   'Duration': 605},
#  {'video_name': 'Difference Between PBFT vs FBA Explained in 60 Seconds',
#   'Likes': '35',
#   'Views': '885',
#   'Total_Count': '0',
#   'Duration': 59},
#  {'video_name': 'What is a Firewall Explained, Types of Firewalls & Deployment Architectures',
#   'Likes': '39',
#   'Views': '3450',
#   'Total_Count': '2',
#   'Duration': 559},
#  {'video_name': 'What is a Firewall Explained in 60 Seconds? 🔥🛡️ #shorts',
#   'Likes': '53',
#   'Views': '964',
#   'Total_Count': '2',
#   'Duration': 57},
#  {'video_name': 'Byzantine Fault Tolerance in Blockchain | Classic Generals Problem & its Solutions: PBFT & FBA',
#   'Likes': '34',
#   'Views': '4872',
#   'Total_Count': '2',
#   'Duration': 408},
#  {'video_name': 'What is Data Science Project Life Cycle Explained Step by Step | ML Lifecycle Steps',
#   'Likes': '75',
#   'Views': '2971',
#   'Total_Count': '11',
#   'Duration': 563},
#  {'video_name': 'Top Software Architecture Visualization Tools For Beginners #shorts',
#   'Likes': '55',
#   'Views': '1173',
#   'Total_Count': '2',
#   'Duration': 60},
#  {'video_name': 'All Major Google Penalties Explained & How to Fix Them in 8 Minutes | 15+ Google Penalty Types',
#   'Likes': '23',
#   'Views': '6168',
#   'Total_Count': '4',
#   'Duration': 488},
#  {'video_name': 'What is Codebase in Programming Explained #shorts',
#   'Likes': '47',
#   'Views': '1198',
#   'Total_Count': '0',
#   'Duration': 52},
#  {'video_name': 'What is Waterfall Methodology in Project Management #shorts',
#   'Likes': '124',
#   'Views': '2941',
#   'Total_Count': '0',
#   'Duration': 49},
#  {'video_name': 'What is Dry Development Principle in Software Engineering #shorts',
#   'Likes': '17',
#   'Views': '741',
#   'Total_Count': '0',
#   'Duration': 56},
#  {'video_name': 'What is Legacy Code in Software Engineering Explained in 1 Minute #Shorts',
#   'Likes': '39',
#   'Views': '619',
#   'Total_Count': '2',
#   'Duration': 48},
#  {'video_name': 'What is Pseudocode Explained | How to Write Pseudocode Algorithm | Examples, Benefits & Steps',
#   'Likes': '207',
#   'Views': '15813',
#   'Total_Count': '9',
#   'Duration': 279},
#  {'video_name': 'What is a Mesh Network Explained in 60 Seconds #shorts',
#   'Likes': '56',
#   'Views': '1470',
#   'Total_Count': '4',
#   'Duration': 41},
#  {'video_name': 'Difference Between Master Slave vs Client Server Software Architecture Explained #shorts',
#   'Likes': '43',
#   'Views': '1568',
#   'Total_Count': '1',
#   'Duration': 60},
#  {'video_name': 'What is a Data Model Explained in 60 Seconds #shorts',
#   'Likes': '298',
#   'Views': '7706',
#   'Total_Count': '1',
#   'Duration': 48},
#  {'video_name': 'Difference Between Traditional CMS vs Headless CMS Explained #shorts',
#   'Likes': '72',
#   'Views': '1806',
#   'Total_Count': '4',
#   'Duration': 58},
#  {'video_name': 'All Major Software Architecture Patterns Explained in 7 Minutes | Meaning, Design, Models & Examples',
#   'Likes': '167',
#   'Views': '22631',
#   'Total_Count': '5',
#   'Duration': 461},
#  {'video_name': 'What is P2P or Peer to Peer Architecture Explained #shorts',
#   'Likes': '121',
#   'Views': '3898',
#   'Total_Count': '0',
#   'Duration': 50},
#  {'video_name': 'What is CRUD Operations in Database Explained in 60 Seconds #Shorts',
#   'Likes': '203',
#   'Views': '4833',
#   'Total_Count': '3',
#   'Duration': 52},
#  {'video_name': 'What are Microservices Explained in 1 Minute #shorts',
#   'Likes': '86',
#   'Views': '2411',
#   'Total_Count': '0',
#   'Duration': 57},
#  {'video_name': 'What is DevSecOps Explained in 1 Minute',
#   'Likes': '90',
#   'Views': '2552',
#   'Total_Count': '0',
#   'Duration': 46},
#  {'video_name': 'What is Containerization in Devops explained',
#   'Likes': '73',
#   'Views': '2105',
#   'Total_Count': '0',
#   'Duration': 48},
#  {'video_name': 'What is Agile Explained in Simple Terms #shorts',
#   'Likes': '185',
#   'Views': '6739',
#   'Total_Count': '1',
#   'Duration': 46},
#  {'video_name': 'What is FOTA (or Firmware Over The Air) in IoT Explained #shorts',
#   'Likes': '44',
#   'Views': '1301',
#   'Total_Count': '0',
#   'Duration': 45},
#  {'video_name': 'What is Big Data Explained in 1 Minute',
#   'Likes': '202',
#   'Views': '5265',
#   'Total_Count': '2',
#   'Duration': 55},
#  {'video_name': 'What is an API Explained in 1 minute #shorts',
#   'Likes': '1292',
#   'Views': '32114',
#   'Total_Count': '8',
#   'Duration': 46},
#  {'video_name': 'What is BaaS or Blockchain as a Service Explained #Shorts',
#   'Likes': '29',
#   'Views': '513',
#   'Total_Count': '0',
#   'Duration': 52},
#  {'video_name': 'What is Deep Learning Explained in 1 Minute #shorts',
#   'Likes': '349',
#   'Views': '8115',
#   'Total_Count': '3',
#   'Duration': 46},
#  {'video_name': 'What is MAC Address Explained in Less Than 60 Seconds #Shorts',
#   'Likes': '86',
#   'Views': '2547',
#   'Total_Count': '2',
#   'Duration': 43},
#  {'video_name': 'What is Cross Site Scripting (or XSS) Vulnerability in Cybersecurity',
#   'Likes': '350',
#   'Views': '7678',
#   'Total_Count': '1',
#   'Duration': 59},
#  {'video_name': 'What is Data Processing Explained in 60 Seconds #Shorts',
#   'Likes': '218',
#   'Views': '4984',
#   'Total_Count': '2',
#   'Duration': 60},
#  {'video_name': 'What is SAP EWM Explained | Introduction to SAP EWM Overview & Basics',
#   'Likes': '252',
#   'Views': '17096',
#   'Total_Count': '14',
#   'Duration': 485},
#  {'video_name': 'Public Cloud vs Private Cloud vs Hybrid Cloud | Types of Cloud Storage Models',
#   'Likes': '53',
#   'Views': '4634',
#   'Total_Count': '7',
#   'Duration': 251},
#  {'video_name': 'Block vs Object vs File Storage | Cloud Storage Types Explained',
#   'Likes': '159',
#   'Views': '11041',
#   'Total_Count': '15',
#   'Duration': 451},
#  {'video_name': 'What is Cloud Storage and How Does it Work | Cloud Storage Explained',
#   'Likes': '94',
#   'Views': '10041',
#   'Total_Count': '6',
#   'Duration': 376},
#  {'video_name': 'Similarities & Difference Between API and Microservices Explained',
#   'Likes': '45',
#   'Views': '8457',
#   'Total_Count': '2',
#   'Duration': 398},
#  {'video_name': 'What are Microservices Explained for Dummies | With Examples, Types, Components & Benefits',
#   'Likes': '50',
#   'Views': '8556',
#   'Total_Count': '2',
#   'Duration': 599},
#  {'video_name': 'Why Digital Marketers Should Use a VPN',
#   'Likes': '29',
#   'Views': '786',
#   'Total_Count': '0',
#   'Duration': 58},
#  {'video_name': 'Difference Between Frontend and Backend | Back End vs Front End',
#   'Likes': '2117',
#   'Views': '46631',
#   'Total_Count': '16',
#   'Duration': 60},
#  {'video_name': 'What is SAP PM Explained | Introduction to SAP PM Overview & Basics',
#   'Likes': '190',
#   'Views': '14037',
#   'Total_Count': '7',
#   'Duration': 436},
#  {'video_name': 'Web 3.0 Architecture & Web3 Tech Stack for Beginners | Web2 vs Web3 Architecture',
#   'Likes': '148',
#   'Views': '11416',
#   'Total_Count': '19',
#   'Duration': 786},
#  {'video_name': 'What is SAP IBP Explained | Introduction to SAP IBP Overview & Basics',
#   'Likes': '229',
#   'Views': '19343',
#   'Total_Count': '11',
#   'Duration': 439},
#  {'video_name': 'How to Become a DevOps Engineer from Scratch | DevOps Learning Path for Beginners',
#   'Likes': '87',
#   'Views': '6286',
#   'Total_Count': '9',
#   'Duration': 560},
#  {'video_name': 'What is DevOps Explained for Beginners #Shorts',
#   'Likes': '196',
#   'Views': '4909',
#   'Total_Count': '1',
#   'Duration': 55},
#  {'video_name': 'What is a Governance Token Explained in Crypto | Why are Governance Tokens Valuable',
#   'Likes': '44',
#   'Views': '6431',
#   'Total_Count': '2',
#   'Duration': 289},
#  {'video_name': 'What is Homomorphic Encryption Explained | Paillier Cryptosystem | PHE | SHE | FHE',
#   'Likes': '205',
#   'Views': '13128',
#   'Total_Count': '14',
#   'Duration': 356},
#  {'video_name': 'What is the Classic Blockchain Trilemma Explained #Shorts',
#   'Likes': '50',
#   'Views': '1432',
#   'Total_Count': '2',
#   'Duration': 59},
#  {'video_name': 'What is Blockchain Layer 0, 1, 2, 3 Explained | Layers of Blockchain Architecture',
#   'Likes': '610',
#   'Views': '28372',
#   'Total_Count': '30',
#   'Duration': 661},
#  {'video_name': 'Supervised vs Unsupervised vs Reinforcement Learning | ML Types Explained | Machine Learning Basics',
#   'Likes': '127',
#   'Views': '7659',
#   'Total_Count': '12',
#   'Duration': 533},
#  {'video_name': 'Stateful vs Stateless Protocol Explained (with Examples, Advantages & Disadvantages)',
#   'Likes': '146',
#   'Views': '10781',
#   'Total_Count': '18',
#   'Duration': 534},
#  {'video_name': 'What is NFT and How it Works? | Non Fungible Token | NFT Explained for Beginners',
#   'Likes': '55',
#   'Views': '7436',
#   'Total_Count': '40',
#   'Duration': 395},
#  {'video_name': '40+ NFT Terms To Know | NFT Terms 101 | NFT Glossary',
#   'Likes': '65',
#   'Views': '3235',
#   'Total_Count': '23',
#   'Duration': 999},
#  {'video_name': 'What is Single Shard Attack in Blockchain Explained #Shorts',
#   'Likes': '26',
#   'Views': '1147',
#   'Total_Count': '9',
#   'Duration': 55},
#  {'video_name': 'What is Sharding in Blockchain Explained | How Does Sharding Works',
#   'Likes': '115',
#   'Views': '6778',
#   'Total_Count': '12',
#   'Duration': 481},
#  {'video_name': 'What is Web 3.0 Explained | Web 1.0 vs Web 2.0 vs Web 3.0 Crypto',
#   'Likes': '390',
#   'Views': '23512',
#   'Total_Count': '15',
#   'Duration': 410},
#  {'video_name': 'What is a Crypto Wallet Explained | Cryptocurrency Wallet #Shorts',
#   'Likes': '73',
#   'Views': '2252',
#   'Total_Count': '0',
#   'Duration': 59},
#  {'video_name': 'What is SAP FICO Explained | Introduction to SAP FICO Overview & Basics',
#   'Likes': '3123',
#   'Views': '138157',
#   'Total_Count': '68',
#   'Duration': 441},
#  {'video_name': 'What is Gas Limit in Ethereum Blockchain Explained #Shorts',
#   'Likes': '44',
#   'Views': '1264',
#   'Total_Count': '0',
#   'Duration': 59},
#  {'video_name': 'What is Bitcoin Halving Explained | BTC Halving History, Need, Impact & Effects',
#   'Likes': '36',
#   'Views': '3410',
#   'Total_Count': '4',
#   'Duration': 442},
#  {'video_name': 'What is Staking in Crypto | Cryptocurrency Staking Explained',
#   'Likes': '70',
#   'Views': '9988',
#   'Total_Count': '10',
#   'Duration': 622},
#  {'video_name': 'How to Audit Facebook Ads for Better ROI | 5-Step Process',
#   'Likes': '68',
#   'Views': '5071',
#   'Total_Count': '1',
#   'Duration': 697},
#  {'video_name': 'Difference Between Data Management vs Data Governance #Shorts',
#   'Likes': '311',
#   'Views': '8244',
#   'Total_Count': '4',
#   'Duration': 55},
#  {'video_name': 'What is Decentralized Exchange Explained | How it Works, Types & Features | DEX Crypto',
#   'Likes': '92',
#   'Views': '10761',
#   'Total_Count': '14',
#   'Duration': 722},
#  {'video_name': 'Difference Between Authentication vs Authorization Explained #Shorts',
#   'Likes': '90',
#   'Views': '1906',
#   'Total_Count': '3',
#   'Duration': 58},
#  {'video_name': 'Difference Between Data Science vs Data Analytics #Shorts',
#   'Likes': '4713',
#   'Views': '79742',
#   'Total_Count': '24',
#   'Duration': 60},
#  {'video_name': 'Data Mart vs Database vs Data Warehouse vs Data Lake Explained',
#   'Likes': '376',
#   'Views': '24645',
#   'Total_Count': '14',
#   'Duration': 534},
#  {'video_name': 'What is DAO in Crypto Explained | How Does Decentralized Autonomous Organization Work',
#   'Likes': '168',
#   'Views': '15198',
#   'Total_Count': '21',
#   'Duration': 809},
#  {'video_name': 'Is CPU Mining Even Worth the Ether? | CPU Eth Mining #Shorts',
#   'Likes': '157',
#   'Views': '4955',
#   'Total_Count': '2',
#   'Duration': 58},
#  {'video_name': 'What is Impermanent Loss in Crypto Explained with Example | How to Calculate & Avoid it',
#   'Likes': '52',
#   'Views': '8261',
#   'Total_Count': '4',
#   'Duration': 538},
#  {'video_name': 'How to Check if an Ethereum Address is Valid | Eth Address Check #Shorts',
#   'Likes': '77',
#   'Views': '2891',
#   'Total_Count': '6',
#   'Duration': 59},
#  {'video_name': '3 Top Image Optimization Tips for Website #Shorts',
#   'Likes': '76',
#   'Views': '1574',
#   'Total_Count': '0',
#   'Duration': 52},
#  {'video_name': 'Difference Between Programming Language and Scripting Language #Shorts',
#   'Likes': '491',
#   'Views': '11306',
#   'Total_Count': '5',
#   'Duration': 45},
#  {'video_name': '3 Top Github Repositories for Beginners #Shorts',
#   'Likes': '95',
#   'Views': '1546',
#   'Total_Count': '2',
#   'Duration': 41},
#  {'video_name': '3 Future Programming Languages To Learn Before 2030 #Shorts',
#   'Likes': '3245',
#   'Views': '59357',
#   'Total_Count': '38',
#   'Duration': 59},
#  {'video_name': 'Is Blockchain Secure? A Short Perspective on Blockchain Security #Shorts',
#   'Likes': '105',
#   'Views': '1992',
#   'Total_Count': '0',
#   'Duration': 49},
#  {'video_name': 'What is a Coin Burn in Crypto? #Shorts',
#   'Likes': '295',
#   'Views': '7705',
#   'Total_Count': '2',
#   'Duration': 58},
#  {'video_name': '10+ ML & AI Career Path with Salaries | How to Start Career in AI and ML',
#   'Likes': '325',
#   'Views': '16181',
#   'Total_Count': '31',
#   'Duration': 681},
#  {'video_name': 'What is a Dapp Explained: Features, Advantages, Types | Decentralized Apps in Blockchain',
#   'Likes': '178',
#   'Views': '9809',
#   'Total_Count': '14',
#   'Duration': 378},
#  {'video_name': 'What is SAP PP Explained | Introduction to SAP PP Overview & Basics',
#   'Likes': '913',
#   'Views': '48052',
#   'Total_Count': '45',
#   'Duration': 642},
#  {'video_name': 'What is Yield Farming in Crypto: Risks, Returns & Working | Staking vs Yield Farming Explained',
#   'Likes': '140',
#   'Views': '11626',
#   'Total_Count': '46',
#   'Duration': 750},
#  {'video_name': 'What is DeFi in Blockchain | Decentralized Finance Explained',
#   'Likes': '91',
#   'Views': '4292',
#   'Total_Count': '12',
#   'Duration': 685},
#  {'video_name': 'Introduction to Blockchain Security Issues & Vulnerabilities | Blockchain Security Explained',
#   'Likes': '366',
#   'Views': '20015',
#   'Total_Count': '13',
#   'Duration': 736},
#  {'video_name': 'Difference Between Encryption vs Encoding vs Hashing vs Obfuscation Explained',
#   'Likes': '189',
#   'Views': '7835',
#   'Total_Count': '11',
#   'Duration': 411},
#  {'video_name': '6 Types of Cryptocurrency Explained | Crypto Types',
#   'Likes': '515',
#   'Views': '28386',
#   'Total_Count': '30',
#   'Duration': 450},
#  {'video_name': 'ANN vs CNN vs RNN | Difference Between ANN CNN and RNN | Types of Neural Networks Explained',
#   'Likes': '1703',
#   'Views': '74251',
#   'Total_Count': '25',
#   'Duration': 339},
#  {'video_name': '5 Top IoT Hacking Tools | Hacker Tools Used in Internet of Things (IoT)',
#   'Likes': '122',
#   'Views': '7272',
#   'Total_Count': '0',
#   'Duration': 340},
#  {'video_name': 'What is Kyma in SAP | SAP KYMA Explained',
#   'Likes': '66',
#   'Views': '6632',
#   'Total_Count': '2',
#   'Duration': 273},
#  {'video_name': 'Difference Between Blockchain And Database | Blockchain vs Database Comparison #Shorts',
#   'Likes': '118',
#   'Views': '2639',
#   'Total_Count': '10',
#   'Duration': 60},
#  {'video_name': '60+ Top Cryptocurrency Explained Simply in 10 Minutes | All Crypto Coins Explained',
#   'Likes': '149',
#   'Views': '9201',
#   'Total_Count': '47',
#   'Duration': 801},
#  {'video_name': 'Difference Between Blockchain And Linked List | Blockchain vs Linked List #Shorts',
#   'Likes': '148',
#   'Views': '3604',
#   'Total_Count': '0',
#   'Duration': 56},
#  {'video_name': 'Different Types of Penetration Testing Methods Explained',
#   'Likes': '102',
#   'Views': '6820',
#   'Total_Count': '5',
#   'Duration': 492},
#  {'video_name': '10 Top Blockchain Project Ideas for Beginners and Students | Blockchain Projects 2021',
#   'Likes': '1610',
#   'Views': '71404',
#   'Total_Count': '51',
#   'Duration': 410},
#  {'video_name': 'Proof of Work vs Proof of Stake vs Proof of Authority Explained | PoA vs PoW vs PoS Blockchain',
#   'Likes': '279',
#   'Views': '21442',
#   'Total_Count': '32',
#   'Duration': 563},
#  {'video_name': 'What are Smart Contracts in Blockchain, its Importance & How Smart Contracts Work',
#   'Likes': '133',
#   'Views': '11104',
#   'Total_Count': '23',
#   'Duration': 482},
#  {'video_name': 'What is Hashing in Blockchain | Blockchain Hashing Explained',
#   'Likes': '97',
#   'Views': '8673',
#   'Total_Count': '9',
#   'Duration': 350},
#  {'video_name': 'Blockchain vs Hashgraph vs DAG vs Holochain | Types of DLT Explained',
#   'Likes': '386',
#   'Views': '14961',
#   'Total_Count': '64',
#   'Duration': 845},
#  {'video_name': 'What is Tokenomics Explained | Tokenomics 101: Everything You Need To Know',
#   'Likes': '1458',
#   'Views': '68035',
#   'Total_Count': '75',
#   'Duration': 682},
#  {'video_name': 'Blockchain Protocol Explained | Top 5 Enterprise Blockchain Protocols You Need to Know',
#   'Likes': '188',
#   'Views': '9881',
#   'Total_Count': '15',
#   'Duration': 512},
#  {'video_name': 'Difference Between Proxy Server And VPN | VPN vs Proxy Server Explained',
#   'Likes': '135',
#   'Views': '7813',
#   'Total_Count': '10',
#   'Duration': 353},
#  {'video_name': 'Cheat Sheet for Content Marketing | Top 5 Content Optimization Tips #Shorts',
#   'Likes': '46',
#   'Views': '687',
#   'Total_Count': '0',
#   'Duration': 59},
#  {'video_name': 'Saas vs Paas vs Iaas vs Xaas Explained | What’s the Difference, Limitations, & Examples',
#   'Likes': '123',
#   'Views': '8603',
#   'Total_Count': '7',
#   'Duration': 822},
#  {'video_name': 'What is Doxing in Ethical Hacking | Doxxing Explained (Working & How to Prevent it)',
#   'Likes': '70',
#   'Views': '4643',
#   'Total_Count': '6',
#   'Duration': 445},
#  {'video_name': 'Surface Web vs Deep Web vs Dark Web vs Darknet Explained',
#   'Likes': '213',
#   'Views': '16511',
#   'Total_Count': '47',
#   'Duration': 391},
#  {'video_name': 'Difference Between VPN and RDP | VPN vs RDP Explained',
#   'Likes': '353',
#   'Views': '23764',
#   'Total_Count': '26',
#   'Duration': 288},
#  {'video_name': 'Blockchain Prerequisites | Blockchain Learning Path to Kickstart Your Journey',
#   'Likes': '149',
#   'Views': '5166',
#   'Total_Count': '30',
#   'Duration': 348},
#  {'video_name': 'How to Become an Ethical Hacker For Beginners | Ethical Hacker Skills Required',
#   'Likes': '137',
#   'Views': '5738',
#   'Total_Count': '12',
#   'Duration': 283},
#  {'video_name': "3T's on How to Tell Your Idea #Shorts",
#   'Likes': '28',
#   'Views': '385',
#   'Total_Count': '0',
#   'Duration': 49},
#  {'video_name': 'What is Ethereum 2.0 And Why Does it Matter | Ethereum vs Ethereum 2.0 Explained',
#   'Likes': '48',
#   'Views': '6739',
#   'Total_Count': '9',
#   'Duration': 313},
#  {'video_name': 'Difference Between Penetration Testing And Ethical Hacking',
#   'Likes': '127',
#   'Views': '5606',
#   'Total_Count': '6',
#   'Duration': 145},
#  {'video_name': 'Difference Between Blockchain and Distributed Ledger Technology #Shorts',
#   'Likes': '116',
#   'Views': '4907',
#   'Total_Count': '5',
#   'Duration': 54},
#  {'video_name': '3 Top Digital Marketing Books to NOT Miss On in 2021 #Shorts',
#   'Likes': '222',
#   'Views': '3556',
#   'Total_Count': '4',
#   'Duration': 53},
#  {'video_name': '3 Books to Improve Your Coding Skills in 2021 and Beyond #shorts',
#   'Likes': '1589',
#   'Views': '17499',
#   'Total_Count': '5',
#   'Duration': 53},
#  {'video_name': '28+ Important Blockchain Terms Explained | Blockchain Terminology',
#   'Likes': '186',
#   'Views': '5863',
#   'Total_Count': '15',
#   'Duration': 402},
#  {'video_name': 'What is Behavioral Data Science Explained in 60 Seconds #Shorts',
#   'Likes': '270',
#   'Views': '7136',
#   'Total_Count': '2',
#   'Duration': 57},
#  {'video_name': 'The Lean Startup Book Summary in 60 seconds | Bullet Summary of The Lean Startup | Eric Ries #shorts',
#   'Likes': '301',
#   'Views': '5406',
#   'Total_Count': '1',
#   'Duration': 60},
#  {'video_name': '7 Skills Needed to Become a Blockchain Developer | Blockchain Developer Career Path',
#   'Likes': '6373',
#   'Views': '193366',
#   'Total_Count': '395',
#   'Duration': 406},
#  {'video_name': '3 Tips on How to Improve Editing Skills For Better Writing #Shorts',
#   'Likes': '358',
#   'Views': '5987',
#   'Total_Count': '3',
#   'Duration': 59},
#  {'video_name': '3 Best Books to Learn Data Science for Beginners #Shorts',
#   'Likes': '2268',
#   'Views': '33428',
#   'Total_Count': '9',
#   'Duration': 59},
#  {'video_name': '3 SQL Tips for Data Scientists & Data Engineers #Shorts',
#   'Likes': '6670',
#   'Views': '149535',
#   'Total_Count': '9',
#   'Duration': 59},
#  {'video_name': '9 Blockchain Career Path with Salaries | How to Start Career in Blockchain',
#   'Likes': '853',
#   'Views': '34812',
#   'Total_Count': '72',
#   'Duration': 309},
#  {'video_name': 'Beginners Guide to Learn Blockchain | How to Become a Blockchain Professional',
#   'Likes': '65',
#   'Views': '1168',
#   'Total_Count': '8',
#   'Duration': 180},
#  {'video_name': 'Introduction to Cryptography in Blockchain Explained | Blockchain Cryptography',
#   'Likes': '290',
#   'Views': '13253',
#   'Total_Count': '29',
#   'Duration': 538},
#  {'video_name': 'Types of Blockchain Explained | Blockchain Types',
#   'Likes': '584',
#   'Views': '24707',
#   'Total_Count': '25',
#   'Duration': 250},
#  {'video_name': 'Public vs Private Blockchain | Difference Between Public and Private Blockchain',
#   'Likes': '351',
#   'Views': '15970',
#   'Total_Count': '28',
#   'Duration': 373},
#  {'video_name': 'What is Forking in Blockchain | Blockchain Forking Explained',
#   'Likes': '121',
#   'Views': '5087',
#   'Total_Count': '17',
#   'Duration': 386},
#  {'video_name': 'What is Blockchain Technology and How Does it Work | Blockchain Explained in 6 minutes',
#   'Likes': '244',
#   'Views': '15105',
#   'Total_Count': '26',
#   'Duration': 403},
#  {'video_name': '7 Common Keyword Research Mistakes to Avoid at all Cost',
#   'Likes': '20',
#   'Views': '368',
#   'Total_Count': '2',
#   'Duration': 517},
#  {'video_name': 'Keyword Research for SEO: What it is, Importance, How to do Keyword Research, Tools + Tips to Use',
#   'Likes': '24',
#   'Views': '1054',
#   'Total_Count': '11',
#   'Duration': 700},
#  {'video_name': 'What is Keyword Density or Keyphrase Density in SEO Explained',
#   'Likes': '51',
#   'Views': '2886',
#   'Total_Count': '7',
#   'Duration': 360},
#  {'video_name': '9 Genius & Best Facebook Ad Hacks of All Time | FB Ad Hacks 2023',
#   'Likes': '90',
#   'Views': '4381',
#   'Total_Count': '17',
#   'Duration': 645},
#  {'video_name': '9 Top Data Science Certifications to Boost Your Career in 2021',
#   'Likes': '145',
#   'Views': '4383',
#   'Total_Count': '6',
#   'Duration': 301},
#  {'video_name': 'What is SAP MM Explained | Introduction to SAP MM Basics',
#   'Likes': '2403',
#   'Views': '110059',
#   'Total_Count': '90',
#   'Duration': 286},
#  {'video_name': '12 Futuristic AI & ML Project Ideas [Updated 2021]',
#   'Likes': '827',
#   'Views': '58074',
#   'Total_Count': '20',
#   'Duration': 508},
#  {'video_name': 'What is Cornerstone Content: Importance, Link Structure & How to Optimize Cornerstone Article',
#   'Likes': '65',
#   'Views': '3622',
#   'Total_Count': '4',
#   'Duration': 257},
#  {'video_name': 'What is Keyword Stemming in SEO',
#   'Likes': '28',
#   'Views': '1221',
#   'Total_Count': '0',
#   'Duration': 125},
#  {'video_name': '6 Side Hustles to Earn Extra Money as a Data Scientist',
#   'Likes': '100',
#   'Views': '4130',
#   'Total_Count': '13',
#   'Duration': 293},
#  {'video_name': '9 Priceless Robert Kiyosaki Lessons Every Entrepreneur Should Follow',
#   'Likes': '24',
#   'Views': '1016',
#   'Total_Count': '5',
#   'Duration': 646},
#  {'video_name': 'What are LSI Keywords? Benefits? Tools? How to Find LSI Keywords?',
#   'Likes': '154',
#   'Views': '7156',
#   'Total_Count': '13',
#   'Duration': 353},
#  {'video_name': 'When NOT to use Machine Learning (ML) or Artificial Intelligence (AI)',
#   'Likes': '45',
#   'Views': '1384',
#   'Total_Count': '2',
#   'Duration': 246},
#  {'video_name': 'Difference Between AI vs ML vs DL vs Data Science Explained',
#   'Likes': '133',
#   'Views': '11311',
#   'Total_Count': '10',
#   'Duration': 412},
#  {'video_name': 'What is Google People Card? How to Create Google People Card? Why it matters?',
#   'Likes': '87',
#   'Views': '6572',
#   'Total_Count': '16',
#   'Duration': 121},
#  {'video_name': '10 Top Skills Needed to Become a Data Scientist in 2023',
#   'Likes': '53',
#   'Views': '2710',
#   'Total_Count': '6',
#   'Duration': 324},
#  {'video_name': '5 Top Skills Needed for Machine Learning Engineer | ML Engineer Skill Set 2023',
#   'Likes': '72',
#   'Views': '2974',
#   'Total_Count': '7',
#   'Duration': 231},
#  {'video_name': 'How to Learn Data Science Step by Step for FREE | Data Science Learning Path for Beginners 2023',
#   'Likes': '221',
#   'Views': '11609',
#   'Total_Count': '27',
#   'Duration': 288},
#  {'video_name': "How to Find Competitor's Facebook Ads in 3 Steps | Spy FB Ads 2021",
#   'Likes': '776',
#   'Views': '31311',
#   'Total_Count': '53',
#   'Duration': 174},
#  {'video_name': 'What is SAP QM Explained | Introduction to SAP QM Basics',
#   'Likes': '370',
#   'Views': '19757',
#   'Total_Count': '26',
#   'Duration': 190},
#  {'video_name': 'What is SAP SD Explained | Introduction to SAP SD Basics',
#   'Likes': '1558',
#   'Views': '72708',
#   'Total_Count': '80',
#   'Duration': 297},
#  {'video_name': 'What is Deep Learning and How it Works | Deep Learning Explained',
#   'Likes': '312',
#   'Views': '27154',
#   'Total_Count': '15',
#   'Duration': 286},
#  {'video_name': '10 Best AI Tools for SEO Success in 2023',
#   'Likes': '134',
#   'Views': '4503',
#   'Total_Count': '6',
#   'Duration': 336},
#  {'video_name': '10 Top Deep Learning Frameworks 2023',
#   'Likes': '47',
#   'Views': '3687',
#   'Total_Count': '8',
#   'Duration': 266},
#  {'video_name': 'What is SAP Fiori? Benefits, Types, Design Principles & Deployment Options',
#   'Likes': '322',
#   'Views': '22684',
#   'Total_Count': '19',
#   'Duration': 232},
#  {'video_name': 'What is SAP Hybris? Benefits of SAP Hybris? Why use it? | SAP Commerce Cloud',
#   'Likes': '480',
#   'Views': '42280',
#   'Total_Count': '34',
#   'Duration': 189},
#  {'video_name': 'What is VPN and How Does it Works, Benefits & How to use it',
#   'Likes': '40',
#   'Views': '2244',
#   'Total_Count': '2',
#   'Duration': 183},
#  {'video_name': 'What is SAP HANA Explained | Introduction to SAP HANA Basics for Beginners',
#   'Likes': '2054',
#   'Views': '145483',
#   'Total_Count': '52',
#   'Duration': 196},
#  {'video_name': '15 Best & FREE Code Editors for Web Developers in 2021',
#   'Likes': '27',
#   'Views': '1546',
#   'Total_Count': '5',
#   'Duration': 298},
#  {'video_name': 'What is API in Programming and How it Works | API Explained for Dummies',
#   'Likes': '526',
#   'Views': '27068',
#   'Total_Count': '20',
#   'Duration': 224},
#  {'video_name': '11 Extremely Useful & Best Chrome Extensions for Web Developers 2021',
#   'Likes': '66',
#   'Views': '954',
#   'Total_Count': '0',
#   'Duration': 288},
#  {'video_name': '11 Best Python Packages for Data Science',
#   'Likes': '80',
#   'Views': '3180',
#   'Total_Count': '2',
#   'Duration': 310},
#  {'video_name': "What are Google's Core Web Vitals in SEO | Tips to Optimize & Where to Find Them",
#   'Likes': '36',
#   'Views': '1858',
#   'Total_Count': '16',
#   'Duration': 298},
#  {'video_name': '11 Best VSCode Extensions For Programmers | Top Visual Studio Code Extensions 2021',
#   'Likes': '71',
#   'Views': '1039',
#   'Total_Count': '16',
#   'Duration': 241},
#  {'video_name': 'Difference Between ML Algorithm and ML Model | ML Algorithm vs Model',
#   'Likes': '268',
#   'Views': '10740',
#   'Total_Count': '8',
#   'Duration': 144},
#  {'video_name': '10 Clever & Best LinkedIn Hacks That Nobody Told You 2021',
#   'Likes': '320',
#   'Views': '18354',
#   'Total_Count': '34',
#   'Duration': 333},
#  {'video_name': 'What is Crawl Budget in SEO | How to do Crawl Budget Optimization',
#   'Likes': '59',
#   'Views': '1998',
#   'Total_Count': '5',
#   'Duration': 214},
#  {'video_name': 'What is Neural Network and How it Works | Neural Network Explained',
#   'Likes': '189',
#   'Views': '13769',
#   'Total_Count': '8',
#   'Duration': 225},
#  {'video_name': 'What is Boilerplate Code in Programming',
#   'Likes': '634',
#   'Views': '29141',
#   'Total_Count': '15',
#   'Duration': 125},
#  {'video_name': '10 Assets that Can Make You RICH & Wealthy 🤑',
#   'Likes': '38',
#   'Views': '1767',
#   'Total_Count': '4',
#   'Duration': 325},
#  {'video_name': 'Top 10 Best Android Emulators for PC and Mac (2021 Edition)',
#   'Likes': '262',
#   'Views': '24703',
#   'Total_Count': '30',
#   'Duration': 271},
#  {'video_name': '20 Best LinkedIn Profile Tips 2021 | How to Make a Great LinkedIn Profile',
#   'Likes': '26',
#   'Views': '3805',
#   'Total_Count': '4',
#   'Duration': 441},
#  {'video_name': '3 Best FREE Instagram Scheduler App | Tools to Schedule IGTV Posts & Stories',
#   'Likes': '763',
#   'Views': '36229',
#   'Total_Count': '70',
#   'Duration': 140},
#  {'video_name': 'Machine Learning Model Deployment Explained | All About ML Model Deployment',
#   'Likes': '434',
#   'Views': '17334',
#   'Total_Count': '13',
#   'Duration': 225},
#  {'video_name': '15 Best Android Libraries for Developers | Top Android Libraries 2021',
#   'Likes': '258',
#   'Views': '11659',
#   'Total_Count': '8',
#   'Duration': 356},
#  {'video_name': 'What is Serverless Architecture Explained | Faas | Serverless Computing Explained',
#   'Likes': '45',
#   'Views': '1566',
#   'Total_Count': '0',
#   'Duration': 175},
#  {'video_name': '7 Basic Machine Learning Concepts for Beginners | Basic ML Concepts',
#   'Likes': '414',
#   'Views': '16457',
#   'Total_Count': '6',
#   'Duration': 267},
#  {'video_name': '9 Facebook Marketing Mistakes to Avoid + Solutions | FB Marketing Mistakes',
#   'Likes': '23',
#   'Views': '587',
#   'Total_Count': '5',
#   'Duration': 362},
#  {'video_name': 'All Machine Learning Models Explained in 5 Minutes | Types of ML Models Basics',
#   'Likes': '23829',
#   'Views': '948047',
#   'Total_Count': '369',
#   'Duration': 301},
#  {'video_name': '9 Best JavaScript Testing Frameworks & Libraries To Use | Top JS Testing Frameworks',
#   'Likes': '62',
#   'Views': '3452',
#   'Total_Count': '2',
#   'Duration': 237},
#  {'video_name': '8 Medium Hacks to Boost Your Earnings | Medium.com Hacks',
#   'Likes': '130',
#   'Views': '2262',
#   'Total_Count': '11',
#   'Duration': 179},
#  {'video_name': '10 Best Landing Page Optimization Tips | Landing Page Best Practices',
#   'Likes': '25',
#   'Views': '387',
#   'Total_Count': '6',
#   'Duration': 261},
#  {'video_name': 'What is Growth Hacking & How Can You Benefit From it | Growth Hacking Meaning',
#   'Likes': '16',
#   'Views': '574',
#   'Total_Count': '0',
#   'Duration': 107},
#  {'video_name': 'What are Protocol Buffers & When to Use them | Protobuf vs JSON',
#   'Likes': '519',
#   'Views': '33089',
#   'Total_Count': '26',
#   'Duration': 203},
#  {'video_name': 'What is Value Proposition Statement | Value Proposition Explained (With Examples)',
#   'Likes': '572',
#   'Views': '48611',
#   'Total_Count': '7',
#   'Duration': 179},
#  {'video_name': '11 Top Android Studio Plugins for Faster Development',
#   'Likes': '237',
#   'Views': '16047',
#   'Total_Count': '14',
#   'Duration': 197},
#  {'video_name': 'What is Crawlability and Indexability in SEO | Whiteboard Marketing',
#   'Likes': '24',
#   'Views': '1017',
#   'Total_Count': '13',
#   'Duration': 193},
#  {'video_name': '10 Top Github Repos for Every Developer (Essentials) | Best GitHub Repositories',
#   'Likes': '195',
#   'Views': '4573',
#   'Total_Count': '13',
#   'Duration': 274},
#  {'video_name': 'What is Schema Markup in SEO | Types of Schema Markup SEO | What is Rich Snippet',
#   'Likes': '62',
#   'Views': '2595',
#   'Total_Count': '4',
#   'Duration': 181},
#  {'video_name': 'What is Search Intent in SEO (With Examples) | Types of Search Intent in SEO',
#   'Likes': '29',
#   'Views': '1085',
#   'Total_Count': '7',
#   'Duration': 158},
#  {'video_name': '5 Fundamental Concepts of Programming Languages | Basic Concepts of Programming for Beginners',
#   'Likes': '1185',
#   'Views': '49445',
#   'Total_Count': '25',
#   'Duration': 218},
#  {'video_name': 'What is SEO Explained | Types of SEO | On Page vs Off Page SEO',
#   'Likes': '12',
#   'Views': '302',
#   'Total_Count': '2',
#   'Duration': 92},
#  {'video_name': '3 Effects of Having a HIGH Bounce Rate on a Website | Whiteboard Marketing',
#   'Likes': '6',
#   'Views': '131',
#   'Total_Count': '0',
#   'Duration': 118},
#  {'video_name': 'What is a Canonical URL in SEO | Use of Canonical Tag in SEO | URL Canonicalization',
#   'Likes': '46',
#   'Views': '3065',
#   'Total_Count': '10',
#   'Duration': 119},
#  {'video_name': 'What is User Journey in SEO | Whiteboard Marketing',
#   'Likes': '6',
#   'Views': '152',
#   'Total_Count': '2',
#   'Duration': 91},
#  {'video_name': 'What is Keyword Gap Analysis in SEO | Benefits & Tools | Whiteboard Entrepreneur',
#   'Likes': '22',
#   'Views': '715',
#   'Total_Count': '2',
#   'Duration': 86},
#  {'video_name': 'What is KPI in Marketing | KPI vs Metric | Whiteboard Entrepreneur',
#   'Likes': '7',
#   'Views': '214',
#   'Total_Count': '0',
#   'Duration': 97},
#  {'video_name': 'What is Entrepreneurship? | Whiteboard Entrepreneur',
#   'Likes': '35',
#   'Views': '1629',
#   'Total_Count': '4',
#   'Duration': 106},
#  {'video_name': 'What is Bounce Rate? | Whiteboard Entrepreneur',
#   'Likes': '5',
#   'Views': '112',
#   'Total_Count': '0',
#   'Duration': 65},
#  {'video_name': 'What is Innovation? (Concept) | Innovation vs Invention | Whiteboard Entrepreneur',
#   'Likes': '23',
#   'Views': '934',
#   'Total_Count': '4',
#   'Duration': 156},
#  {'video_name': 'Why Try ZIG-ZAG Marketing? | Whiteboard Entrepreneur',
#   'Likes': '5',
#   'Views': '236',
#   'Total_Count': '0',
#   'Duration': 111},
#  {'video_name': '4 Ps of Marketing Mix Explained | Whiteboard Entrepreneur',
#   'Likes': '15',
#   'Views': '800',
#   'Total_Count': '0',
#   'Duration': 116},
#  {'video_name': 'What is Marketing, Really? | Whiteboard Entrepreneur',
#   'Likes': '11',
#   'Views': '385',
#   'Total_Count': '0',
#   'Duration': 79},
#  {'video_name': '9 Best Chatbots for Wordpress for Business (Pros & Cons) | Best Wordpress Chatbot Plugins',
#   'Likes': '42',
#   'Views': '3076',
#   'Total_Count': '8',
#   'Duration': 318},
#  {'video_name': 'How to Create a Chatbot for FREE for WordPress (in less than 3 Minutes)',
#   'Likes': '126',
#   'Views': '5481',
#   'Total_Count': '7',
#   'Duration': 174}]

# %% [markdown]
# # Function to get comments

# %%
def get_video_comments(youtube, channel_id):
    video_id_list = get_video_ids(youtube, channel_id)
    all_video_comments = []  # Initialize a list to store comments for all videos

    for video in video_id_list:
        request = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video,
            maxResults=50
        )
        response = request.execute()

        video_comments = []  # Initialize a list to store comments for the current video
        
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            video_comments.append(comment)  # Append comment to the list of comments for this video
        
        next_page_token = response.get('nextPageToken')
        more_pages = True
    
        while more_pages:
            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.commentThreads().list(
                            part='snippet,replies',
                            videoId=video,
                            maxResults=50,
                            pageToken = next_page_token    
                            )
                response = request.execute()

                for item in response['items']:
                    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
                    video_comments.append(comment)
                next_page_token = response.get('nextPageToken')
            
            
             # Append the list of comments for this video to the overall list
        all_video_comments.append({video: video_comments})
    return all_video_comments

# %%
get_video_comments(youtube, 'UCbZr6zxHZq0eFpVBeU-7IgQ')
# Out:
# [{'xNy-7LlnBfU': ['kjhghjkl']},
#  {'yOhEigi55pc': ['kjhghjklkjh']},
#  {'O1H4mZNAZDQ': []},
#  {'ao1DADw9u54': []}]

# %%
channel_id = input("Enter Channel ID:")
my_dict = {
    get_channel_stats(youtube, channel_id):{
        get_video_ids(youtube, channel_id):{
            get_video_stats(youtube, channel_id):get_video_comments(youtube, channel_id)
        }
    }
    
    
}
# Out:
# Enter Channel ID:UCbZr6zxHZq0eFpVBeU-7IgQ
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7b63ed338dcd> in <module>
#       3     get_channel_stats(youtube, channel_id):{
#       4         get_video_ids(youtube, channel_id):{
# ----> 5             get_video_stats(youtube, channel_id):get_video_comments(youtube, channel_id)
#       6         }
#       7     }
#
# TypeError: unhashable type: 'list'

# %%
channel_id = input("Enter Channel ID:")

# Fetch data
channel_stats = get_channel_stats(youtube, channel_id)
video_ids = get_video_ids(youtube, channel_id)
video_stats = [get_video_stats(youtube, channel_id) for video_id in video_ids]
video_comments = [get_video_comments(youtube, video_id) for video_id in video_ids]

# Create a nested dictionary
youtube_data = {
    channel_id: {
        "channel_stats": channel_stats,
        "videos": {
            video_id: {
                "video_stats": video_stat,
                "comments": video_comment
            }
            for video_id, video_stat, video_comment in zip(video_ids, video_stats, video_comments)
        }
    }
}

print(youtube_data)
# Out:
# Enter Channel ID:UCbZr6zxHZq0eFpVBeU-7IgQ
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-073fcfd80a11> in <module>
#       4 channel_stats = get_channel_stats(youtube, channel_id)
#       5 video_ids = get_video_ids(youtube, channel_id)
# ----> 6 video_stats = [get_video_stats(youtube, video_id) for video_id in video_ids]
#       7 video_comments = [get_video_comments(youtube, video_id) for video_id in video_ids]
#       8
#
# <ipython-input-9-073fcfd80a11> in <listcomp>(.0)
#       4 channel_stats = get_channel_stats(youtube, channel_id)
#       5 video_ids = get_video_ids(youtube, channel_id)
# ----> 6 video_stats = [get_video_stats(youtube, video_id) for video_id in video_ids]
#       7 video_comments = [get_video_comments(youtube, video_id) for video_id in video_ids]
#       8
#
# <ipython-input-6-9344f2203d1d> in get_video_stats(youtube, channel_id)
#       2
#       3 def get_video_stats(youtube, channel_id):
# ----> 4     video_id = get_video_ids(youtube, channel_id)
#       5     video_stat=[]
#       6     for video in video_id:
#
# <ipython-input-5-80a86594f97a> in get_video_ids(youtube, channel_id)
#      11
#      12 def get_video_ids(youtube, channel_id):
# ---> 13     playlist_id = get_playlist_id(youtube, channel_id)  # Call the function to get the playlist ID
#      14
#      15     request = youtube.playlistItems().list(
#
# <ipython-input-5-80a86594f97a> in get_playlist_id(youtube, channel_id)
#       6     response = request.execute()
#       7
# ----> 8     playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
#       9
#      10     return playlist_id
#
# KeyError: 'items'
